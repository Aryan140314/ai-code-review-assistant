# %%
import os
import pandas as pd

print(os.getcwd())  # debug: see where you are

df = pd.read_csv("dataset.csv")

print(df["label"].value_counts())
# Out:
# e:\ai-code-review\ml
# label
# 1873     1
# 180      1
# 17061    1
# 21548    1
# 6987     1
#         ..
# 5734     1
# 3577     1
# 2479     1
# 1559     1
# 10456    1
# Name: count, Length: 10927, dtype: int64
